# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to make a local copy of the MNIST 1D repository
#!git clone https://github.com/greydanus/mnist1d

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Length of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  # loop over the dataset n_epoch times
  n_epoch = 1000

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TO DO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;
errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Train the model
    errors_train, errors_test = fit_model(model, data)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.298382, train error 89.28,  test loss 2.297746, test error 89.80
# Epoch   100, train loss 1.910585, train error 72.45,  test loss 1.756671, test error 69.00
# Epoch   200, train loss 1.898871, train error 72.22,  test loss 1.721197, test error 68.95
# Epoch   300, train loss 1.900664, train error 71.95,  test loss 1.725816, test error 68.85
# Epoch   400, train loss 1.898434, train error 71.93,  test loss 1.714511, test error 68.47
# Epoch   500, train loss 1.893359, train error 71.32,  test loss 1.713754, test error 68.95
# Epoch   600, train loss 1.893758, train error 71.55,  test loss 1.712308, test error 68.68
# Epoch   700, train loss 1.898579, train error 72.00,  test loss 1.720873, test error 68.93
# Epoch   800, train loss 1.893019, train error 71.05,  test loss 1.712072, test error 68.43
# Epoch   900, train loss 1.892690, train error 71.68,  test loss 1.710050, test error 68.35
# Training model with   4 hidden variables
# Epoch     0, train loss 2.301937, train error 89.03,  test loss 2.302866, test error 89.32
# Epoch   100, train loss 1.764120, train error 66.05,  test loss 1.600286, test error 62.42
# Epoch   200, train loss 1.713134, train error 62.53,  test loss 1.514515, test error 57.95
# Epoch   300, train loss 1.699176, train error 61.25,  test loss 1.508746, test error 57.50
# Epoch   400, train loss 1.688077, train error 61.42,  test loss 1.496795, test error 57.12
# Epoch   500, train loss 1.687855, train error 61.58,  test loss 1.496995, test error 57.90
# Epoch   600, train loss 1.688820, train error 61.80,  test loss 1.497107, test error 57.85
# Epoch   700, train loss 1.687157, train error 61.75,  test loss 1.508448, test error 57.95
# Epoch   800, train loss 1.683071, train error 61.40,  test loss 1.496400, test error 57.20
# Epoch   900, train loss 1.685407, train error 61.53,  test loss 1.506310, test error 57.97
# Training model with   6 hidden variables
# Epoch     0, train loss 2.275056, train error 86.05,  test loss 2.268437, test error 84.22
# Epoch   100, train loss 1.677568, train error 59.30,  test loss 1.489586, test error 57.58
# Epoch   200, train loss 1.656239, train error 58.33,  test loss 1.475841, test error 57.67
# Epoch   300, train loss 1.643286, train error 58.05,  test loss 1.472945, test error 57.70
# Epoch   400, train loss 1.637196, train error 57.70,  test loss 1.474551, test error 58.60
# Epoch   500, train loss 1.637414, train error 57.85,  test loss 1.487379, test error 59.12
# Epoch   600, train loss 1.632642, train error 57.53,  test loss 1.476660, test error 58.50
# Epoch   700, train loss 1.639377, train error 58.22,  test loss 1.503899, test error 58.97
# Epoch   800, train loss 1.628452, train error 57.72,  test loss 1.481505, test error 58.75
# Epoch   900, train loss 1.632001, train error 57.72,  test loss 1.482325, test error 58.90
# Training model with   8 hidden variables
# Epoch     0, train loss 2.268834, train error 86.47,  test loss 2.269894, test error 87.25
# Epoch   100, train loss 1.658177, train error 59.28,  test loss 1.524719, test error 58.88
# Epoch   200, train loss 1.618795, train error 57.42,  test loss 1.489230, test error 57.60
# Epoch   300, train loss 1.600183, train error 56.60,  test loss 1.491859, test error 56.95
# Epoch   400, train loss 1.591718, train error 56.75,  test loss 1.493214, test error 56.35
# Epoch   500, train loss 1.585039, train error 56.92,  test loss 1.504252, test error 56.78
# Epoch   600, train loss 1.579903, train error 56.85,  test loss 1.528618, test error 57.12
# Epoch   700, train loss 1.566195, train error 55.80,  test loss 1.517121, test error 57.20
# Epoch   800, train loss 1.566033, train error 56.00,  test loss 1.511220, test error 56.08
# Epoch   900, train loss 1.562259, train error 56.15,  test loss 1.524637, test error 56.62
# Training model with  10 hidden variables
# Epoch     0, train loss 2.211170, train error 82.22,  test loss 2.208217, test error 83.40
# Epoch   100, train loss 1.523381, train error 51.03,  test loss 1.375811, test error 51.28
# Epoch   200, train loss 1.473251, train error 50.10,  test loss 1.355649, test error 50.70
# Epoch   300, train loss 1.457391, train error 50.15,  test loss 1.342035, test error 50.72
# Epoch   400, train loss 1.454270, train error 49.72,  test loss 1.362967, test error 50.92
# Epoch   500, train loss 1.436928, train error 48.90,  test loss 1.358479, test error 50.75
# Epoch   600, train loss 1.434613, train error 48.90,  test loss 1.364104, test error 51.62
# Epoch   700, train loss 1.427045, train error 48.60,  test loss 1.363708, test error 51.62
# Epoch   800, train loss 1.419002, train error 49.17,  test loss 1.361276, test error 50.72
# Epoch   900, train loss 1.418525, train error 49.70,  test loss 1.369319, test error 51.70
# Training model with  14 hidden variables
# Epoch     0, train loss 2.188926, train error 83.32,  test loss 2.158406, test error 81.53
# Epoch   100, train loss 1.509694, train error 51.50,  test loss 1.477309, test error 57.10
# Epoch   200, train loss 1.428884, train error 48.20,  test loss 1.454781, test error 54.50
# Epoch   300, train loss 1.357425, train error 44.78,  test loss 1.372383, test error 51.12
# Epoch   400, train loss 1.329405, train error 44.08,  test loss 1.357062, test error 49.53
# Epoch   500, train loss 1.301601, train error 43.42,  test loss 1.357250, test error 49.08
# Epoch   600, train loss 1.286672, train error 42.72,  test loss 1.364459, test error 49.85
# Epoch   700, train loss 1.279598, train error 42.12,  test loss 1.375555, test error 49.85
# Epoch   800, train loss 1.276602, train error 42.97,  test loss 1.390793, test error 50.85
# Epoch   900, train loss 1.270788, train error 43.00,  test loss 1.387336, test error 50.55
# Training model with  18 hidden variables
# Epoch     0, train loss 2.227073, train error 84.15,  test loss 2.203773, test error 82.75
# Epoch   100, train loss 1.364541, train error 45.62,  test loss 1.350226, test error 49.90
# Epoch   200, train loss 1.227075, train error 41.85,  test loss 1.355653, test error 49.62
# Epoch   300, train loss 1.167752, train error 39.88,  test loss 1.404464, test error 49.35
# Epoch   400, train loss 1.137525, train error 38.55,  test loss 1.453120, test error 50.08
# Epoch   500, train loss 1.125983, train error 37.88,  test loss 1.484643, test error 50.00
# Epoch   600, train loss 1.116520, train error 37.78,  test loss 1.508209, test error 50.35
# Epoch   700, train loss 1.120918, train error 38.28,  test loss 1.533387, test error 50.17
# Epoch   800, train loss 1.109843, train error 38.42,  test loss 1.541378, test error 49.53
# Epoch   900, train loss 1.104475, train error 38.05,  test loss 1.547574, test error 49.17
# Training model with  22 hidden variables
# Epoch     0, train loss 2.213463, train error 82.68,  test loss 2.210687, test error 82.90
# Epoch   100, train loss 1.279161, train error 42.15,  test loss 1.276946, test error 48.55
# Epoch   200, train loss 1.144287, train error 38.65,  test loss 1.352913, test error 48.28
# Epoch   300, train loss 1.071355, train error 35.93,  test loss 1.450406, test error 51.20
# Epoch   400, train loss 1.028655, train error 34.93,  test loss 1.516799, test error 49.83
# Epoch   500, train loss 1.003408, train error 33.75,  test loss 1.586488, test error 50.75
# Epoch   600, train loss 0.987754, train error 33.18,  test loss 1.643172, test error 50.10
# Epoch   700, train loss 0.963547, train error 32.55,  test loss 1.724648, test error 51.40
# Epoch   800, train loss 0.955439, train error 32.32,  test loss 1.766659, test error 51.28
# Epoch   900, train loss 0.942681, train error 32.32,  test loss 1.833386, test error 51.58
# Training model with  26 hidden variables
# Epoch     0, train loss 2.158013, train error 80.40,  test loss 2.129228, test error 79.03
# Epoch   100, train loss 1.186807, train error 39.10,  test loss 1.349890, test error 49.33
# Epoch   200, train loss 1.032074, train error 34.80,  test loss 1.513256, test error 50.78
# Epoch   300, train loss 0.951237, train error 31.85,  test loss 1.653442, test error 51.55
# Epoch   400, train loss 0.901740, train error 29.90,  test loss 1.771387, test error 52.85
# Epoch   500, train loss 0.872406, train error 30.47,  test loss 1.855249, test error 53.58
# Epoch   600, train loss 0.861438, train error 29.25,  test loss 1.934725, test error 53.10
# Epoch   700, train loss 0.823338, train error 27.68,  test loss 1.966455, test error 54.15
# Epoch   800, train loss 0.815064, train error 28.12,  test loss 2.024434, test error 53.65
# Epoch   900, train loss 0.802380, train error 27.43,  test loss 2.103217, test error 54.55
# Training model with  30 hidden variables
# Epoch     0, train loss 2.132009, train error 79.70,  test loss 2.089791, test error 78.43
# Epoch   100, train loss 1.139845, train error 38.05,  test loss 1.401532, test error 50.70
# Epoch   200, train loss 0.959150, train error 32.05,  test loss 1.552113, test error 51.42
# Epoch   300, train loss 0.858022, train error 28.80,  test loss 1.705222, test error 51.80
# Epoch   400, train loss 0.824414, train error 27.62,  test loss 1.937441, test error 53.55
# Epoch   500, train loss 0.760961, train error 25.75,  test loss 2.053805, test error 53.80
# Epoch   600, train loss 0.748814, train error 26.05,  test loss 2.251700, test error 55.47
# Epoch   700, train loss 0.699962, train error 24.22,  test loss 2.373074, test error 55.30
# Epoch   800, train loss 0.674237, train error 23.03,  test loss 2.555811, test error 55.85
# Epoch   900, train loss 0.670540, train error 23.57,  test loss 2.675339, test error 55.50
# Training model with  35 hidden variables
# Epoch     0, train loss 2.123452, train error 77.57,  test loss 2.099875, test error 78.10
# Epoch   100, train loss 1.001559, train error 33.78,  test loss 1.427614, test error 50.05
# Epoch   200, train loss 0.777740, train error 26.07,  test loss 1.743950, test error 52.42
# Epoch   300, train loss 0.635091, train error 21.62,  test loss 2.112381, test error 52.75
# Epoch   400, train loss 0.567268, train error 19.47,  test loss 2.493421, test error 54.28
# Epoch   500, train loss 0.538869, train error 18.25,  test loss 2.843413, test error 54.72
# Epoch   600, train loss 0.502667, train error 17.68,  test loss 3.160540, test error 55.85
# Epoch   700, train loss 0.458240, train error 15.60,  test loss 3.445882, test error 55.58
# Epoch   800, train loss 0.447044, train error 15.03,  test loss 3.814247, test error 56.20
# Epoch   900, train loss 0.416988, train error 13.65,  test loss 4.065814, test error 55.83
# Training model with  40 hidden variables
# Epoch     0, train loss 2.094723, train error 77.53,  test loss 2.052202, test error 76.62
# Epoch   100, train loss 0.916439, train error 30.12,  test loss 1.479745, test error 50.92
# Epoch   200, train loss 0.646676, train error 21.07,  test loss 1.914686, test error 51.92
# Epoch   300, train loss 0.517167, train error 17.55,  test loss 2.601386, test error 53.65
# Epoch   400, train loss 0.478156, train error 16.78,  test loss 3.333653, test error 55.62
# Epoch   500, train loss 0.354513, train error 11.97,  test loss 4.048507, test error 55.53
# Epoch   600, train loss 0.340709, train error 12.00,  test loss 4.835758, test error 56.35
# Epoch   700, train loss 0.309689, train error 11.22,  test loss 5.566421, test error 57.05
# Epoch   800, train loss 0.263028, train error 9.15,  test loss 6.202784, test error 56.78
# Epoch   900, train loss 0.271912, train error 9.88,  test loss 6.857420, test error 57.03
# Training model with  45 hidden variables
# Epoch     0, train loss 2.056562, train error 77.32,  test loss 1.990680, test error 76.93
# Epoch   100, train loss 0.808959, train error 26.57,  test loss 1.503372, test error 49.90
# Epoch   200, train loss 0.515432, train error 16.68,  test loss 2.157736, test error 51.85
# Epoch   300, train loss 0.312460, train error 9.30,  test loss 3.065627, test error 53.60
# Epoch   400, train loss 0.216038, train error 6.50,  test loss 4.104229, test error 54.47
# Epoch   500, train loss 0.148017, train error 4.82,  test loss 5.408998, test error 55.12
# Epoch   600, train loss 0.068203, train error 1.22,  test loss 6.682900, test error 55.95
# Epoch   700, train loss 0.020259, train error 0.05,  test loss 7.548670, test error 55.25
# Epoch   800, train loss 0.008757, train error 0.00,  test loss 8.382381, test error 55.12
# Epoch   900, train loss 0.006296, train error 0.00,  test loss 8.908695, test error 55.55
# Training model with  50 hidden variables
# Epoch     0, train loss 2.094911, train error 77.97,  test loss 2.050182, test error 78.97
# Epoch   100, train loss 0.685669, train error 20.93,  test loss 1.622167, test error 51.00
# Epoch   200, train loss 0.284543, train error 7.30,  test loss 2.728402, test error 54.55
# Epoch   300, train loss 0.119589, train error 2.68,  test loss 4.417300, test error 55.15
# Epoch   400, train loss 0.021322, train error 0.00,  test loss 5.807556, test error 56.15
# Epoch   500, train loss 0.010929, train error 0.00,  test loss 6.589722, test error 56.53
# Epoch   600, train loss 0.007209, train error 0.00,  test loss 7.130648, test error 56.62
# Epoch   700, train loss 0.005320, train error 0.00,  test loss 7.545141, test error 56.80
# Epoch   800, train loss 0.004141, train error 0.00,  test loss 7.880012, test error 57.00
# Epoch   900, train loss 0.003374, train error 0.00,  test loss 8.162022, test error 56.78
# Training model with  55 hidden variables
# Epoch     0, train loss 2.100742, train error 76.85,  test loss 2.098134, test error 78.30
# Epoch   100, train loss 0.655807, train error 19.65,  test loss 1.636096, test error 50.60
# Epoch   200, train loss 0.217586, train error 4.72,  test loss 2.911414, test error 54.55
# Epoch   300, train loss 0.049443, train error 0.12,  test loss 4.570293, test error 54.55
# Epoch   400, train loss 0.015944, train error 0.00,  test loss 5.613144, test error 54.42
# Epoch   500, train loss 0.008881, train error 0.00,  test loss 6.244741, test error 54.17
# Epoch   600, train loss 0.006083, train error 0.00,  test loss 6.687291, test error 54.42
# Epoch   700, train loss 0.004559, train error 0.00,  test loss 7.028513, test error 54.50
# Epoch   800, train loss 0.003562, train error 0.00,  test loss 7.312757, test error 54.78
# Epoch   900, train loss 0.002934, train error 0.00,  test loss 7.549823, test error 54.78
# Training model with  60 hidden variables
# Epoch     0, train loss 2.108791, train error 78.57,  test loss 2.084905, test error 78.30
# Epoch   100, train loss 0.505694, train error 14.53,  test loss 1.658182, test error 49.75
# Epoch   200, train loss 0.103988, train error 0.93,  test loss 3.245096, test error 54.10
# Epoch   300, train loss 0.020063, train error 0.00,  test loss 4.544437, test error 54.40
# Epoch   400, train loss 0.009596, train error 0.00,  test loss 5.225406, test error 54.53
# Epoch   500, train loss 0.006073, train error 0.00,  test loss 5.649899, test error 54.33
# Epoch   600, train loss 0.004293, train error 0.00,  test loss 5.979707, test error 54.60
# Epoch   700, train loss 0.003290, train error 0.00,  test loss 6.242875, test error 54.58
# Epoch   800, train loss 0.002640, train error 0.00,  test loss 6.455900, test error 54.70
# Epoch   900, train loss 0.002194, train error 0.00,  test loss 6.636431, test error 54.62
# Training model with  70 hidden variables
# Epoch     0, train loss 2.039713, train error 75.95,  test loss 1.993452, test error 76.20
# Epoch   100, train loss 0.390218, train error 11.35,  test loss 1.984783, test error 51.60
# Epoch   200, train loss 0.031209, train error 0.00,  test loss 3.613656, test error 52.72
# Epoch   300, train loss 0.010514, train error 0.00,  test loss 4.378664, test error 52.65
# Epoch   400, train loss 0.005900, train error 0.00,  test loss 4.807593, test error 52.83
# Epoch   500, train loss 0.003961, train error 0.00,  test loss 5.103878, test error 52.70
# Epoch   600, train loss 0.002942, train error 0.00,  test loss 5.331836, test error 52.67
# Epoch   700, train loss 0.002309, train error 0.00,  test loss 5.517742, test error 52.92
# Epoch   800, train loss 0.001889, train error 0.00,  test loss 5.671357, test error 52.92
# Epoch   900, train loss 0.001588, train error 0.00,  test loss 5.803598, test error 52.97
# Training model with  80 hidden variables
# Epoch     0, train loss 2.006077, train error 74.95,  test loss 1.964485, test error 75.60
# Epoch   100, train loss 0.241096, train error 3.95,  test loss 2.111914, test error 52.10
# Epoch   200, train loss 0.020325, train error 0.00,  test loss 3.491736, test error 53.67
# Epoch   300, train loss 0.008087, train error 0.00,  test loss 4.056810, test error 53.17
# Epoch   400, train loss 0.004774, train error 0.00,  test loss 4.390436, test error 53.30
# Epoch   500, train loss 0.003293, train error 0.00,  test loss 4.627170, test error 53.38
# Epoch   600, train loss 0.002477, train error 0.00,  test loss 4.808987, test error 53.22
# Epoch   700, train loss 0.001967, train error 0.00,  test loss 4.957466, test error 53.50
# Epoch   800, train loss 0.001618, train error 0.00,  test loss 5.082187, test error 53.40
# Epoch   900, train loss 0.001368, train error 0.00,  test loss 5.190672, test error 53.40
# Training model with  90 hidden variables
# Epoch     0, train loss 1.991148, train error 74.22,  test loss 1.934571, test error 74.85
# Epoch   100, train loss 0.135301, train error 1.10,  test loss 2.236896, test error 50.65
# Epoch   200, train loss 0.014569, train error 0.00,  test loss 3.315344, test error 51.58
# Epoch   300, train loss 0.006444, train error 0.00,  test loss 3.746609, test error 51.47
# Epoch   400, train loss 0.003957, train error 0.00,  test loss 4.020399, test error 51.53
# Epoch   500, train loss 0.002783, train error 0.00,  test loss 4.216695, test error 51.53
# Epoch   600, train loss 0.002117, train error 0.00,  test loss 4.370850, test error 51.53
# Epoch   700, train loss 0.001695, train error 0.00,  test loss 4.498413, test error 51.38
# Epoch   800, train loss 0.001404, train error 0.00,  test loss 4.605632, test error 51.42
# Epoch   900, train loss 0.001193, train error 0.00,  test loss 4.697485, test error 51.38
# Training model with 100 hidden variables
# Epoch     0, train loss 2.017741, train error 74.72,  test loss 1.954561, test error 74.75
# Epoch   100, train loss 0.103872, train error 0.47,  test loss 2.316193, test error 51.47
# Epoch   200, train loss 0.012211, train error 0.00,  test loss 3.169368, test error 51.53
# Epoch   300, train loss 0.005673, train error 0.00,  test loss 3.550350, test error 51.88
# Epoch   400, train loss 0.003545, train error 0.00,  test loss 3.782675, test error 51.78
# Epoch   500, train loss 0.002519, train error 0.00,  test loss 3.956205, test error 51.95
# Epoch   600, train loss 0.001929, train error 0.00,  test loss 4.091178, test error 52.00
# Epoch   700, train loss 0.001550, train error 0.00,  test loss 4.203795, test error 51.88
# Epoch   800, train loss 0.001288, train error 0.00,  test loss 4.297498, test error 51.88
# Epoch   900, train loss 0.001097, train error 0.00,  test loss 4.380221, test error 51.95
# Training model with 120 hidden variables
# Epoch     0, train loss 1.992046, train error 75.60,  test loss 1.952781, test error 76.80
# Epoch   100, train loss 0.048757, train error 0.00,  test loss 2.265059, test error 49.95
# Epoch   200, train loss 0.009413, train error 0.00,  test loss 2.892844, test error 50.03
# Epoch   300, train loss 0.004687, train error 0.00,  test loss 3.183631, test error 50.03
# Epoch   400, train loss 0.003008, train error 0.00,  test loss 3.366617, test error 49.95
# Epoch   500, train loss 0.002169, train error 0.00,  test loss 3.504137, test error 50.03
# Epoch   600, train loss 0.001678, train error 0.00,  test loss 3.612016, test error 49.95
# Epoch   700, train loss 0.001357, train error 0.00,  test loss 3.702114, test error 49.90
# Epoch   800, train loss 0.001133, train error 0.00,  test loss 3.778869, test error 49.95
# Epoch   900, train loss 0.000969, train error 0.00,  test loss 3.845330, test error 49.83
# Training model with 140 hidden variables
# Epoch     0, train loss 1.958617, train error 71.88,  test loss 1.892568, test error 74.25
# Epoch   100, train loss 0.036628, train error 0.00,  test loss 2.211664, test error 50.20
# Epoch   200, train loss 0.008107, train error 0.00,  test loss 2.717812, test error 50.20
# Epoch   300, train loss 0.004156, train error 0.00,  test loss 2.959944, test error 50.35
# Epoch   400, train loss 0.002693, train error 0.00,  test loss 3.115923, test error 50.45
# Epoch   500, train loss 0.001958, train error 0.00,  test loss 3.234063, test error 50.38
# Epoch   600, train loss 0.001521, train error 0.00,  test loss 3.327210, test error 50.42
# Epoch   700, train loss 0.001234, train error 0.00,  test loss 3.403311, test error 50.35
# Epoch   800, train loss 0.001033, train error 0.00,  test loss 3.469105, test error 50.42
# Epoch   900, train loss 0.000885, train error 0.00,  test loss 3.526192, test error 50.33
# Training model with 160 hidden variables
# Epoch     0, train loss 1.945681, train error 71.88,  test loss 1.866199, test error 73.28
# Epoch   100, train loss 0.028013, train error 0.00,  test loss 2.126369, test error 48.45
# Epoch   200, train loss 0.007184, train error 0.00,  test loss 2.535398, test error 48.58
# Epoch   300, train loss 0.003783, train error 0.00,  test loss 2.737115, test error 48.45
# Epoch   400, train loss 0.002490, train error 0.00,  test loss 2.872077, test error 48.38
# Epoch   500, train loss 0.001824, train error 0.00,  test loss 2.972393, test error 48.40
# Epoch   600, train loss 0.001425, train error 0.00,  test loss 3.052343, test error 48.42
# Epoch   700, train loss 0.001161, train error 0.00,  test loss 3.119892, test error 48.45
# Epoch   800, train loss 0.000975, train error 0.00,  test loss 3.177144, test error 48.42
# Epoch   900, train loss 0.000837, train error 0.00,  test loss 3.227586, test error 48.53
# Training model with 180 hidden variables
# Epoch     0, train loss 1.962825, train error 72.22,  test loss 1.908349, test error 74.12
# Epoch   100, train loss 0.023841, train error 0.00,  test loss 2.093654, test error 49.40
# Epoch   200, train loss 0.006570, train error 0.00,  test loss 2.460860, test error 49.12
# Epoch   300, train loss 0.003528, train error 0.00,  test loss 2.644567, test error 49.38
# Epoch   400, train loss 0.002339, train error 0.00,  test loss 2.767416, test error 49.35
# Epoch   500, train loss 0.001723, train error 0.00,  test loss 2.862081, test error 49.55
# Epoch   600, train loss 0.001350, train error 0.00,  test loss 2.936897, test error 49.53
# Epoch   700, train loss 0.001103, train error 0.00,  test loss 2.998431, test error 49.42
# Epoch   800, train loss 0.000928, train error 0.00,  test loss 3.051574, test error 49.45
# Epoch   900, train loss 0.000798, train error 0.00,  test loss 3.097897, test error 49.47
# Training model with 200 hidden variables
# Epoch     0, train loss 1.940029, train error 71.72,  test loss 1.857414, test error 72.47
# Epoch   100, train loss 0.021705, train error 0.00,  test loss 2.028729, test error 47.78
# Epoch   200, train loss 0.006228, train error 0.00,  test loss 2.360333, test error 47.50
# Epoch   300, train loss 0.003368, train error 0.00,  test loss 2.529388, test error 47.70
# Epoch   400, train loss 0.002244, train error 0.00,  test loss 2.644394, test error 47.62
# Epoch   500, train loss 0.001657, train error 0.00,  test loss 2.730837, test error 47.47
# Epoch   600, train loss 0.001301, train error 0.00,  test loss 2.800202, test error 47.65
# Epoch   700, train loss 0.001064, train error 0.00,  test loss 2.857113, test error 47.85
# Epoch   800, train loss 0.000896, train error 0.00,  test loss 2.906494, test error 47.88
# Epoch   900, train loss 0.000771, train error 0.00,  test loss 2.949481, test error 47.92
# Training model with 250 hidden variables
# Epoch     0, train loss 1.917776, train error 69.25,  test loss 1.820244, test error 70.53
# Epoch   100, train loss 0.017004, train error 0.00,  test loss 1.884778, test error 46.03
# Epoch   200, train loss 0.005326, train error 0.00,  test loss 2.125398, test error 46.60
# Epoch   300, train loss 0.002966, train error 0.00,  test loss 2.255719, test error 46.58
# Epoch   400, train loss 0.002005, train error 0.00,  test loss 2.344646, test error 46.55
# Epoch   500, train loss 0.001492, train error 0.00,  test loss 2.412198, test error 46.53
# Epoch   600, train loss 0.001178, train error 0.00,  test loss 2.466606, test error 46.42
# Epoch   700, train loss 0.000968, train error 0.00,  test loss 2.512409, test error 46.33
# Epoch   800, train loss 0.000817, train error 0.00,  test loss 2.551677, test error 46.22
# Epoch   900, train loss 0.000705, train error 0.00,  test loss 2.586720, test error 46.30
# Training model with 300 hidden variables
# Epoch     0, train loss 1.871718, train error 67.60,  test loss 1.796587, test error 69.90
# Epoch   100, train loss 0.014657, train error 0.00,  test loss 1.815277, test error 45.50
# Epoch   200, train loss 0.004845, train error 0.00,  test loss 2.031202, test error 45.65
# Epoch   300, train loss 0.002738, train error 0.00,  test loss 2.147067, test error 45.33
# Epoch   400, train loss 0.001865, train error 0.00,  test loss 2.226641, test error 45.15
# Epoch   500, train loss 0.001395, train error 0.00,  test loss 2.287291, test error 45.33
# Epoch   600, train loss 0.001105, train error 0.00,  test loss 2.336782, test error 45.40
# Epoch   700, train loss 0.000910, train error 0.00,  test loss 2.377929, test error 45.35
# Epoch   800, train loss 0.000770, train error 0.00,  test loss 2.413415, test error 45.45
# Epoch   900, train loss 0.000665, train error 0.00,  test loss 2.444454, test error 45.40
# Training model with 400 hidden variables
# Epoch     0, train loss 1.833366, train error 65.25,  test loss 1.764204, test error 68.65
# Epoch   100, train loss 0.011438, train error 0.00,  test loss 1.770519, test error 44.62
# Epoch   200, train loss 0.004102, train error 0.00,  test loss 1.947742, test error 44.70
# Epoch   300, train loss 0.002379, train error 0.00,  test loss 2.046652, test error 44.70
# Epoch   400, train loss 0.001641, train error 0.00,  test loss 2.115853, test error 44.75
# Epoch   500, train loss 0.001238, train error 0.00,  test loss 2.168287, test error 44.55
# Epoch   600, train loss 0.000986, train error 0.00,  test loss 2.211536, test error 44.78
# Epoch   700, train loss 0.000815, train error 0.00,  test loss 2.247630, test error 44.80
# Epoch   800, train loss 0.000692, train error 0.00,  test loss 2.278731, test error 44.72
# Epoch   900, train loss 0.000600, train error 0.00,  test loss 2.305872, test error 44.65

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all,'r-',label='train')
ax.plot(hidden_variables, errors_test_all,'b-',label='test')
ax.set_ylim(0,100);
ax.set_xlabel('No hidden variables'); ax.set_ylabel('Error')
ax.legend()
plt.show()
